# %%
import pandas as pd
import numpy as np

# %%
dataframe1 = pd.read_excel('probfalhaativos.xlsx',header=None)

# %%
print(dataframe1)
# Out:
#              0          1     2
# 0   -19.985392 -43.813941  0.60
# 1   -20.190501 -43.865241  0.30
# 2   -20.347961 -43.802507  0.77
# 3   -20.365050 -43.817596  0.85
# 4   -20.351514 -43.816254  0.74
# ..         ...        ...   ...
# 120 -19.973864 -43.897109  0.77
# 121 -19.964855 -43.885930  0.87
# 122 -19.967182 -43.883258  0.74
# 123 -19.857998 -43.804605  0.95
# 124 -19.959845 -43.883522  0.80
#
# [125 rows x 3 columns]

# %%
print(dataframe1[2][0])
# Out:
# 0.6

# %%
dataframe1 = dataframe1.to_numpy()

# %%
dataframe1
# Out:
# array([[-1.99853918e+01, -4.38139406e+01,  6.00000000e-01],
#        [-2.01905008e+01, -4.38652412e+01,  3.00000000e-01],
#        [-2.03479608e+01, -4.38025075e+01,  7.70000000e-01],
#        [-2.03650498e+01, -4.38175964e+01,  8.50000000e-01],
#        [-2.03515145e+01, -4.38162540e+01,  7.40000000e-01],
#        [-2.04693892e+01, -4.38625726e+01,  4.00000000e-01],
#        [-2.04814601e+01, -4.38679135e+01,  5.00000000e-01],
#        [-2.03690022e+01, -4.38161405e+01,  6.00000000e-01],
#        [-2.01820253e+01, -4.38608830e+01,  3.50000000e-01],
#        [-2.01236010e+01, -4.39306338e+01,  5.60000000e-01],
#        [-2.04329729e+01, -4.38443912e+01,  4.30000000e-01],
#        [-2.05002855e+01, -4.38631012e+01,  2.30000000e-01],
#        [-2.04367001e+01, -4.39806533e+01,  1.40000000e-01],
#        [-2.03690767e+01, -4.38877165e+01,  3.00000000e-01],
#        [-2.03889370e+01, -4.38421643e+01,  2.30000000e-01],
#        [-1.99824527e+01, -4.38267942e+01,  7.00000000e-01],
# ...

# %%
print(dataframe1[0,2])
# Out:
# 0.6

# %%
import math

# # Define os parâmetros do problema
num_ativos = 125
num_bases = 14
num_equipes = 3
eta = 0.7

print((num_ativos-(math.ceil(eta * (num_ativos / num_equipes))*num_equipes))-12)
# Out:
# 23
